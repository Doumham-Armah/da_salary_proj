# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
from selenium import webdriver
import time
import pandas as pd
import numpy as np
import math

exps = (NoSuchElementException, StaleElementReferenceException)

# %%
def get_jobs(keyword, pages):
    
    options = webdriver.ChromeOptions()
    
    exec_path_mac = '/Users/mahmoudhamra/Dropbox/GitHub Projects/da_salary_proj/scraping-glassdoor-selenium-master/chromedriver'
    exec_path_pc = 'C:/Users/mahmo/Dropbox/GitHub Projects/da_salary_proj/chromedriver'
    driver = webdriver.Chrome(executable_path=exec_path_pc, options=options)
    

    driver.set_window_size(1120, 1000)
#     url = 'https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword=' + keyword + '&sc.keyword=' + keyword + '&locT=&locId=&jobType='
#     url2 = 'https://www.glassdoor.com/Job/data-analyst-jobs-SRCH_KO0,12.htm?sortBy=date_desc&jobType=fulltime&includeNoSalaryJobs=true'
    url3 = 'https://www.glassdoor.com/Job/california-data-analyst-jobs-SRCH_IL.0,10_IS2280_KO11,23.htm?includeNoSalaryJobs=true&p=1'
    driver.get(url3)
    df = []    
    
    for i in range(pages):
        
        if i>=1:
#             url = 'https://www.glassdoor.com/Job/data-analyst-jobs-SRCH_KO0,12_IP' + str(i+1) + '.htm?includeNoSalaryJobs=true'
#             url2 = 'https://www.glassdoor.com/Job/data-analyst-jobs-SRCH_KO0,12_IP' + str(i+1) + '.htm?sortBy=date_desc&jobType=fulltime&includeNoSalaryJobs=true'
            url3 = 'https://www.glassdoor.com/Job/california-data-analyst-jobs-SRCH_IL.0,10_IS2280_KO11,23_IP' + str(i+1) + '.htm?includeNoSalaryJobs=true&pgc=AB4AAYEAHgAAAAAAAAAAAAAAAaD%2FV8YAQwECAQgUBjNeyDPT4r%2FQHT5PUGPtOXYyy%2B1pfTqdxXH5CxLwOb63vjRFO2JBg2PgVTVWAhnCBlE3CluYSjHOD8MTqJ4AAA%3D%3D'
            driver.get(url2)
        else:
            pass
        
        driver.implicitly_wait(1)
        #collect job listings in the page (30 jobs/page)
        #jobs = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div[1]/div/div[2]/section/article/div[1]/ul/li')
        
        
        jobs = driver.find_elements_by_xpath('.//*[@id="MainCol"]/div[1]/ul/li')
        
        for job in jobs:
            
            print("---------------------------")
            
            # click on job 
            job.click()
            print("JOB BUTTON CLICKED")
            
            #if sign up window pops up close it
            try:
                driver.find_element_by_css_selector('[alt="Close"]').click()  #clicking to the X.
                print("clicked the X button")
            except NoSuchElementException:
                pass

            
            #get company name
            try:
                company_name = job.find_element_by_xpath('//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/').text
                print(company_name)
            except exps:
                company_name = np.nan
                
            try:
                
                job_title = job.find_element_by_xpath('//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[2]').text
                print(job_title)
            except exps:
                job_title = np.nan
                
            
            try:
                rating = job.find_element_by_xpath('//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[1]/span').text
                print(rating)
            except exps:
                rating = np.nan
                
            try:
                salary_estimate = job.find_element_by_xpath('//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[4]/span').text
                print(salary_estimate)
            except exps:
                salary_estimate = np.nan
            
            try:
                location = job.find_element_by_xpath('//*[@id="JDCol"]/div/article/div/div[1]/div/div/div[1]/div[3]/div[1]/div[3]').text
                print(location)
            except exps:
                location = np.nan
                                

            #Looping over Company Overview section and appending information to comp_info list
            comp_info = []
            elems = driver.find_elements_by_xpath('.//div[@id="EmpBasicInfo"]//div//div[@class="d-flex flex-wrap"]//div[@class="d-flex justify-content-start css-rmzuhb e1pvx6aw0"]')
            for element in elems:
                try:
                    driver.implicitly_wait(5)
                    #taking key value pairs ex: 'size', 1001 to 5000 Employees
                    comp_info.append(element.find_element_by_xpath('.//span[@class="css-1taruhi e1pvx6aw1"]').text)
                    comp_info.append(element.find_element_by_xpath('.//span[@class="css-i9gxme e1pvx6aw2"]').text)

                except StaleElementReferenceException:
                    print("##################StaleElementReferenceException")
                        
                    
            # Convert a list to dictionary
            it = iter(comp_info)
            comp_info = dict(zip(it, it))
            
           

            try:
                size = comp_info['Size']
                print(size)
            except KeyError:
                size = "Unknown"
                
                            
            try:
                founded = comp_info['Founded']
                print(founded)
            except KeyError:
                founded = np.nan
                

            try:
                type_of_ownership = comp_info['Type']
                print(type_of_ownership)
            except KeyError:
                type_of_ownership = np.nan
                

            try:
                industry = comp_info['Industry']
                print(industry)
            except KeyError:
                industry = np.nan
                

            try:
                sector = comp_info['Sector']
                print(sector)
            except KeyError:
                sector = np.nan
                

            try:
                revenue = comp_info['Revenue']
                print(revenue)
            except KeyError:
                revenue = np.nan
                
                
            print("---------------------------")
            
            #add job details to df list
            df.append({
            "company_name" : company_name,
            "job_title": job_title,
            "salary_estimate": salary_estimate,
            "location": location,
            "rating" : rating,
            "size" : size,
            "founded" : founded,
            "type_of_ownership" : type_of_ownership,
            "industry" : industry,
            "sector" : sector,
            "revenue" : revenue})
         
    return pd.DataFrame(df)  #This line converts the dictionary object into a pandas DataFrame

# %%
df = get_jobs("data analyst", 30)
# Out:
# ---------------------------
# JOB BUTTON CLICKED
# clicked the X button
# Operations Data Analyst
# 3.2
# $32K - $57K (Glassdoor est.)
# Rancho Cucamonga, CA
# 1001 to 5000 Employees
# 1976
# Company - Private
# Logistics & Supply Chain
# Transportation & Logistics
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Quality Analyst (Shasta County, CA)
# 3.9
# $38K - $44K (Glassdoor est.)
# Redding, CA
# 10000+ Employees
# 1966
# Company - Public
# Architectural & Engineering Services
# Business Services
# $2 to $5 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# E-Commerce Sale Data Analyst(Bilingual)
# Industry, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Senior Product Data Analyst
# San Francisco, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Financial Data Analyst
# 4.0
# Chatsworth, CA
# 201 to 500 Employees
# Company - Private
# Home Furniture & Housewares Stores
# Retail
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Operations Data Analyst
# Oxnard, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Sr. Staff Data Analyst (Consumer Web Products)
# 3.5
# San Mateo, CA
# 1001 to 5000 Employees
# 2002
# Company - Private
# Investment Banking & Asset Management
# Finance
# $500 million to $1 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Sales Data Analyst
# 3.5
# $41K - $74K (Glassdoor est.)
# Carson, CA
# 201 to 500 Employees
# 1986
# Subsidiary or Business Segment
# Consumer Products Manufacturing
# Manufacturing
# $100 to $500 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 3.3
# $42K - $59K (Glassdoor est.)
# San Bernardino, CA
# 201 to 500 Employees
# 1976
# Nonprofit Organization
# Social Assistance
# Non-Profit
# $10 to $25 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst Asset Tracking Admin
# Santa Ana, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst-HEDIS & Star
# 4.1
# $80K - $91K (Glassdoor est.)
# Long Beach, CA
# 501 to 1000 Employees
# 1977
# Nonprofit Organization
# Insurance Carriers
# Insurance
# $2 to $5 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# IT Data Analyst - Administration
# 3.6
# $47K - $59K (Glassdoor est.)
# San Diego, CA
# 1001 to 5000 Employees
# Company - Public
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# $46K - $59K (Glassdoor est.)
# Carlsbad, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Sr. Staff Data Analyst (Marketing Multi Product)
# 3.5
# San Mateo, CA
# 1001 to 5000 Employees
# 2002
# Company - Private
# Investment Banking & Asset Management
# Finance
# $500 million to $1 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Senior Analyst, Data & Analytics
# 4.0
# $61K - $133K (Glassdoor est.)
# San Francisco, CA
# 51 to 200 Employees
# 2011
# Company - Private
# Internet
# Information Technology
# $25 to $50 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Pharmacy Data Analyst
# $53K - $80K (Glassdoor est.)
# Garden Grove, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 3.4
# Sacramento, CA
# 201 to 500 Employees
# Company - Private
# Advertising & Marketing
# Business Services
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 2.8
# $24K - $24K (Glassdoor est.)
# Perris, CA
# 501 to 1000 Employees
# 1971
# Company - Private
# General Merchandise & Superstores
# Retail
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Product Analyst/Data Scientist (Senior or Midlevel)
# 3.9
# $140K - $164K (Glassdoor est.)
# Glendale, CA
# 501 to 1000 Employees
# 2007
# Company - Private
# K-12 Education
# Education
# $100 to $500 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 4.2
# Cupertino, CA
# 1001 to 5000 Employees
# 1997
# Company - Private
# Staffing & Outsourcing
# Business Services
# $100 to $500 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Quality Analyst (Trinity County, CA)
# 3.9
# Weaverville, CA
# 10000+ Employees
# 1966
# Company - Public
# Architectural & Engineering Services
# Business Services
# $2 to $5 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 4.8
# Mountain View, CA
# 51 to 200 Employees
# 1997
# Company - Private
# Consulting
# Business Services
# Unknown / Non-Applicable
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Entry Sourcing Analyst
# 3.5
# Modesto, CA
# 5001 to 10000 Employees
# 1946
# Company - Public
# Staffing & Outsourcing
# Business Services
# $5 to $10 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# 3.5
# Livermore, CA
# 5001 to 10000 Employees
# 1946
# Company - Public
# Staffing & Outsourcing
# Business Services
# $5 to $10 billion (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Technical Data Analyst
# 2.0
# $30K - $52K (Glassdoor est.)
# Ladera Ranch, CA
# 201 to 500 Employees
# 1993
# Company - Private
# Security Services
# Business Services
# $25 to $50 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Security Analyst
# 3.5
# $76K - $87K (Glassdoor est.)
# Burlingame, CA
# 501 to 1000 Employees
# 1996
# Company - Private
# Federal Agencies
# Government
# $10 to $25 million (USD)
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst - YouTube
# San Bruno, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# $75K - $115K (Glassdoor est.)
# Oakland, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Analyst
# Corona, CA
# ---------------------------
# ---------------------------
# JOB BUTTON CLICKED
# Data Quality Analyst (Butte County, CA)
# 3.9
# $32K - $57K (Glassdoor est.)
# Chico, CA
# 10000+ Employees
# 1966
# Company - Public
# Architectural & Engineering Services
# Business Services
# $2 to $5 billion (USD)
# ---------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dc8daea94952> in <module>
# ----> 1 df = get_jobs("data analyst", 30)
#
# <ipython-input-2-2760066c691a> in get_jobs(keyword, pages)
#      21 #             url2 = 'https://www.glassdoor.com/Job/data-analyst-jobs-SRCH_KO0,12_IP' + str(i+1) + '.htm?sortBy=date_desc&jobType=fulltime&includeNoSalaryJobs=true'
#      22             url3 = 'https://www.glassdoor.com/Job/california-data-analyst-jobs-SRCH_IL.0,10_IS2280_KO11,23_IP' + str(i+1) + '.htm?includeNoSalaryJobs=true&pgc=AB4AAYEAHgAAAAAAAAAAAAAAAaD%2FV8YAQwECAQgUBjNeyDPT4r%2FQHT5PUGPtOXYyy%2B1pfTqdxXH5CxLwOb63vjRFO2JBg2PgVTVWAhnCBlE3CluYSjHOD8MTqJ4AAA%3D%3D'
# ---> 23             driver.get(url2)
#      24         else:
#      25             pass
#
# NameError: name 'url2' is not defined

# %%
df.sample(10)

# %%
df.info()

# %%
df.to_csv('jobsCA', index=False)
